# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("price.xlsx")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price($)")
plt.scatter(df.area, df.price, color = "red", marker = "+")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# y = m * x + b

# %%
135.78767123 * 3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %%
reg2 = linear_model.LinearRegression()
reg2.fit(df[['price']], df.area)
# Out:
# LinearRegression()

# %%
reg2.predict([[200000]])
# Out:
# array([273.16421896])

# %%
df2 = pd.read_excel("predict_price.xlsx")

# %%
df2
# Out:
#    area
# 0  1000
# 1  2000
# 2  3000
# 3  3500
# 4  4000

# %%
price = reg.predict(df2)

# %%
df2["price"] = price

# %%
df2
# Out:
#    area          price
# 0  1000  316404.109589
# 1  2000  452191.780822
# 2  3000  587979.452055
# 3  3500  655873.287671
# 4  4000  723767.123288

# %%
df2.to_excel("done_predict_price.xlsx", index = False)
